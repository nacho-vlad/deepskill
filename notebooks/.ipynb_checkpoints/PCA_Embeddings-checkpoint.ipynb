# %%
import sys
sys.path.append('../tgl')
import os
os.chdir('../tgl')

# %%
from model import TemporalGraphModel

# %%
import numpy as np

tgm = TemporalGraphModel('LICHESS', 'config/TGN.yml', 'models/LICHESS_2013-02.pkl')
node_count = tgm.node_count()
all_nodes = np.arange(0, node_count, dtype = int)
ts = np.repeat(tgm.timestamps().max(), len(all_nodes))

# %%
emb = tgm.get_node_emb(all_nodes, ts)
emb
# Out:
# tensor([[ 3.0009, -0.5954, -0.5875,  ..., -0.6002, -0.5616, -0.5319],
#         [-0.4759, -0.4827, -0.4703,  ..., -0.4820, -0.4494, -0.4209],
#         [-0.4474, -0.4539, -0.4403,  ..., -0.4517, -0.4206, -0.3924],
#         ...,
#         [-0.5047, -0.2863, -0.5006,  ...,  0.7055,  0.0624, -0.4495],
#         [-0.5118,  0.4353, -0.5081,  ..., -0.5200, -0.4855, -0.4566],
#         [-0.5254,  1.0056, -0.5223,  ...,  0.0146, -0.4992, -0.4701]])

# %%
from sklearn import decomposition

pca = decomposition.PCA(n_components = 2)
pca
# Out:
# PCA(n_components=2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
pca.fit(emb)
emb_pca = pca.transform(emb)
emb_pca.shape
# Out:
# (4977, 2)

# %%
plt.scatter(emb_pca[:, 0], emb_pca[:, 1], s=1)
plt.axis('equal');

# %%
from sklearn.manifold import TSNE

emb_tsne = TSNE(n_components=2, learning_rate='auto',
                init='random', perplexity=30).fit_transform(emb)
emb_tsne.shape
# Out:
# (4977, 2)

# %%
plt.scatter(emb_tsne[:, 0], emb_tsne[:, 1], s = 1)
plt.axis('equal');
